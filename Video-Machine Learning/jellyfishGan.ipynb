# %% [markdown]
# <a href="https://colab.research.google.com/github/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_07_2_train_gan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # T81-558: Applications of Deep Neural Networks
# **Module 7: Generative Adversarial Networks**
# * Instructor: [Jeff Heaton](https://sites.wustl.edu/jeffheaton/), McKelvey School of Engineering, [Washington University in St. Louis](https://engineering.wustl.edu/Programs/Pages/default.aspx)
# * For more information visit the [class website](https://sites.wustl.edu/jeffheaton/t81-558/).

# %% [markdown]
# # Module 7 Material
#
# * Part 7.1: Introduction to GANs for Image and Data Generation [[Video]](https://www.youtube.com/watch?v=hZw-AjbdN5k&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](https://github.com/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_07_1_gan_intro.ipynb)
# * **Part 7.2: Train StyleGAN3 with your Own Images** [[Video]](https://www.youtube.com/watch?v=R546LYsQk5M&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](https://github.com/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_07_2_train_gan.ipynb)
# * Part 7.3: Exploring the StyleGAN Latent Vector [[Video]](https://www.youtube.com/watch?v=goQzp8QSb2s&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](https://github.com/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_07_3_latent_vector.ipynb)
# * Part 7.4: GANs to Enhance Old Photographs Deoldify [[Video]](https://www.youtube.com/watch?v=0OTd5GlHRx4&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](https://github.com/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_07_4_deoldify.ipynb)
# * Part 7.5: GANs for Tabular Synthetic Data Generation [[Video]](https://www.youtube.com/watch?v=yujdA46HKwA&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](https://github.com/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_07_5_tabular_synthetic.ipynb)

# %% [markdown]
# # Google CoLab Instructions
#
# The following code ensures that Google CoLab is running the correct version of TensorFlow.

# %%
try:
    from google.colab import drive
    drive.mount('/content/drive', force_remount=True)
    COLAB = True
    print("Note: using Google CoLab")
    # %tensorflow_version 2.x
except:
    print("Note: not using Google CoLab")
    COLAB = False
# Out:
# Mounted at /content/drive
# Note: using Google CoLab
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.

# %%
# !pip uninstall tensorflow
# !pip install tensorflow
# Out:
# Found existing installation: tensorflow 2.8.2+zzzcolab20220929150707
# Uninstalling tensorflow-2.8.2+zzzcolab20220929150707:
#   Would remove:
#     /usr/local/bin/estimator_ckpt_converter
#     /usr/local/bin/import_pb_to_tensorboard
#     /usr/local/bin/saved_model_cli
#     /usr/local/bin/tensorboard
#     /usr/local/bin/tf_upgrade_v2
#     /usr/local/bin/tflite_convert
#     /usr/local/bin/toco
#     /usr/local/bin/toco_from_protos
#     /usr/local/lib/python3.7/dist-packages/tensorflow-2.8.2+zzzcolab20220929150707.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/tensorflow/*
# Proceed (y/n)? y
# y
#   Successfully uninstalled tensorflow-2.8.2+zzzcolab20220929150707
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow
#   Downloading tensorflow-2.10.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (578.0 MB)
#      |████████████████████████████████| 578.0 MB 17 kB/s
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.17.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (22.9.24)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.27.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.49.1)
# Collecting keras<2.11,>=2.10.0
#   Downloading keras-2.10.0-py2.py3-none-any.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 65.4 MB/s
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tensorflow) (21.3)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (14.0.6)
# Collecting tensorflow-estimator<2.11,>=2.10.0
#   Downloading tensorflow_estimator-2.10.0-py2.py3-none-any.whl (438 kB)
#      |████████████████████████████████| 438 kB 73.7 MB/s
# Collecting gast<=0.4.0,>=0.2.1
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (2.0.1)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.21.6)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.2.0)
# Collecting tensorboard<2.11,>=2.10
#   Downloading tensorboard-2.10.1-py3-none-any.whl (5.9 MB)
#      |████████████████████████████████| 5.9 MB 73.1 MB/s
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (4.1.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow) (57.4.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow) (1.5.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.23.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow) (1.35.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.4.6)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow) (1.0.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow) (5.0.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow) (3.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (3.2.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tensorflow) (3.0.9)
# Installing collected packages: tensorflow-estimator, tensorboard, keras, gast, tensorflow
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.8.0
#     Uninstalling tensorflow-estimator-2.8.0:
#       Successfully uninstalled tensorflow-estimator-2.8.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.8.0
#     Uninstalling tensorboard-2.8.0:
#       Successfully uninstalled tensorboard-2.8.0
#   Attempting uninstall: keras
#     Found existing installation: keras 2.8.0
#     Uninstalling keras-2.8.0:
#       Successfully uninstalled keras-2.8.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.5.3
#     Uninstalling gast-0.5.3:
#       Successfully uninstalled gast-0.5.3
# Successfully installed gast-0.4.0 keras-2.10.0 tensorboard-2.10.1 tensorflow-2.10.0 tensorflow-estimator-2.10.0

# %% [markdown]
# # Part 7.2: Train StyleGAN3 with your Images
#
# Training GANs with StyleGAN is resource-intensive. The NVIDA StyleGAN researchers used computers with eight high-end GPUs for the high-resolution face GANs trained by NVIDIA. The GPU used by NVIDIA is an A100, which has more memory and cores than the P100 or V100 offered by even Colab Pro+. In this part, we will use StyleGAN2 to train rather than StyleGAN3. You can use networks trained with StyleGAN2 from StyleGAN3; however, StyleGAN3 usually is more effective at training than StyleGAN2.
#
# Unfortunately, StyleGAN3 is compute-intensive and will perform slowly on any GPU that is not the latest Ampere technology. Because Colab does not provide such technology, I am keeping the training guide at the StyleGAN2 level. Switching to StyleGAN3 is relatively easy, as will be pointed out later.
#
# Make sure that you are running this notebook with a GPU runtime. You can train GANs with either Google Colab Free or Pro. I recommend at least the Pro version due to better GPU instances, longer runtimes, and timeouts. Additionally, the capability of Google Colab Pro to run in the background is valuable when training GANs, as you can close your browser or reboot your laptop while training continues.
#
#
#
# You will store your training data and trained neural networks to GDRIVE. For GANs, I lay out my GDRIVE like this:
#
# * ./data/gan/images - RAW images I wish to train on.
# * ./data/gan/datasets - Actual training datasets that I convert from the raw images.
# * ./data/gan/experiments - The output from StyleGAN2, my image previews, and saved network snapshots.
#
# You will mount the drive at the following location.
#
# ```
# /content/drive/MyDrive/data
# ```
#
# ## What Sort of GPU do you Have?
#
# The type of GPU assigned to you by Colab will significantly affect your training time. Some sample times that I achieved with Colab are given here. I've found that Colab Pro generally starts you with a V100, however, if you run scripts non-stop for 24hrs straight for a few days in a row, you will generally be throttled back to a P100.
#
# * 1024x1024 - V100 - 566 sec/tick (CoLab Pro)
# * 1024x1024 - P100 - 1819 sec/tick (CoLab Pro)
# * 1024x1024 - T4 - 2188 sec/tick (CoLab Free)
#
# By comparison, a 1024x1024 GAN trained with StyleGAN3 on a V100 is 3087 sec/tick.
#
# If you use Google CoLab Pro, generally, it will not disconnect before 24 hours, even if you (but not your script) are inactive. Free CoLab WILL disconnect a perfectly good running script if you do not interact for a few hours. The following describes how to circumvent this issue.
#
# * [How to prevent Google Colab from disconnecting?](https://stackoverflow.com/questions/57113226/how-to-prevent-google-colab-from-disconnecting)
#
# ## Set Up New Environment
#
# You will likely need to train for >24 hours. Colab will disconnect you. You must be prepared to restart training when this eventually happens. Training is divided into ticks, every so many ticks (50 by default), your neural network is evaluated, and a snapshot is saved. When CoLab shuts down, all training after the last snapshot is lost. It might seem desirable to snapshot after each tick; however, this snapshotting process itself takes nearly an hour. Learning an optimal snapshot size for your resolution and training data is important.
#
# We will mount GDRIVE so that you will save your snapshots there. You must also place your training images in GDRIVE.
#
# You must also install NVIDIA StyleGAN2 ADA PyTorch. We also need to downgrade PyTorch to a version that supports StyleGAN.

# %%
# !pip install torch==1.8.1 torchvision==0.9.1
# !git clone https://github.com/NVlabs/stylegan2-ada-pytorch.git
# !pip install ninja
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torch==1.8.1
#   Downloading torch-1.8.1-cp37-cp37m-manylinux1_x86_64.whl (804.1 MB)
#      |████████████████████████████████| 804.1 MB 2.6 kB/s
# Collecting torchvision==0.9.1
#   Downloading torchvision-0.9.1-cp37-cp37m-manylinux1_x86_64.whl (17.4 MB)
#      |████████████████████████████████| 17.4 MB 38.9 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.8.1) (4.1.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch==1.8.1) (1.21.6)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.7/dist-packages (from torchvision==0.9.1) (7.1.2)
# Installing collected packages: torch, torchvision
#   Attempting uninstall: torch
#     Found existing installation: torch 1.12.1+cu113
#     Uninstalling torch-1.12.1+cu113:
#       Successfully uninstalled torch-1.12.1+cu113
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.13.1+cu113
#     Uninstalling torchvision-0.13.1+cu113:
#       Successfully uninstalled torchvision-0.13.1+cu113
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.13.1 requires torch==1.12.1, but you have torch 1.8.1 which is incompatible.
# torchaudio 0.12.1+cu113 requires torch==1.12.1, but you have torch 1.8.1 which is incompatible.
# Successfully installed torch-1.8.1 torchvision-0.9.1
# Cloning into 'stylegan2-ada-pytorch'...
# remote: Enumerating objects: 128, done.
# remote: Total 128 (delta 0), reused 0 (delta 0), pack-reused 128
# Receiving objects: 100% (128/128), 1.12 MiB | 838.00 KiB/s, done.
# Resolving deltas: 100% (57/57), done.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ninja
#   Downloading ninja-1.10.2.4-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (120 kB)
#      |████████████████████████████████| 120 kB 32.0 MB/s
# Installing collected packages: ninja
# Successfully installed ninja-1.10.2.4

# %% [markdown]
# ## Find Your Files
#
# The drive is mounted to the following location.
#
# ```
# /content/drive/MyDrive/data
# ```
#
# It might be helpful to use an ```ls``` command to establish the exact path for your images.

# %%
# !ls /content/drive/MyDrive/JellyFish
# Out:
# fish100.jpg  fish22.jpg   fish359.jpg  fish488.jpg  fish616.jpg  fish745.jpg
# fish101.jpg  fish230.jpg  fish35.jpg   fish489.jpg  fish617.jpg  fish746.jpg
# fish102.jpg  fish231.jpg  fish360.jpg  fish48.jpg   fish618.jpg  fish747.jpg
# fish103.jpg  fish232.jpg  fish361.jpg  fish490.jpg  fish619.jpg  fish748.jpg
# fish104.jpg  fish233.jpg  fish362.jpg  fish491.jpg  fish61.jpg	 fish749.jpg
# fish105.jpg  fish234.jpg  fish363.jpg  fish492.jpg  fish620.jpg  fish74.jpg
# fish106.jpg  fish235.jpg  fish364.jpg  fish493.jpg  fish621.jpg  fish750.jpg
# fish107.jpg  fish236.jpg  fish365.jpg  fish494.jpg  fish622.jpg  fish751.jpg
# fish108.jpg  fish237.jpg  fish366.jpg  fish495.jpg  fish623.jpg  fish752.jpg
# fish109.jpg  fish238.jpg  fish367.jpg  fish496.jpg  fish624.jpg  fish753.jpg
# fish10.jpg   fish239.jpg  fish368.jpg  fish497.jpg  fish625.jpg  fish754.jpg
# fish110.jpg  fish23.jpg   fish369.jpg  fish498.jpg  fish626.jpg  fish755.jpg
# fish111.jpg  fish240.jpg  fish36.jpg   fish499.jpg  fish627.jpg  fish756.jpg
# fish112.jpg  fish241.jpg  fish370.jpg  fish49.jpg   fish628.jpg  fish757.jpg
# fish113.jpg  fish242.jpg  fish371.jpg  fish4.jpg    fish629.jpg  fish758.jpg
# fish114.jpg  fish243.jpg  fish372.jpg  fish500.jpg  fish62.jpg	 fish759.jpg
# fish115.jpg  fish244.jpg  fish373.jpg  fish501.jpg  fish630.jpg  fish75.jpg
# fish116.jpg  fish245.jpg  fish374.jpg  fish502.jpg  fish631.jpg  fish760.jpg
# fish117.jpg  fish246.jpg  fish375.jpg  fish503.jpg  fish632.jpg  fish761.jpg
# fish118.jpg  fish247.jpg  fish376.jpg  fish504.jpg  fish633.jpg  fish762.jpg
# fish119.jpg  fish248.jpg  fish377.jpg  fish505.jpg  fish634.jpg  fish763.jpg
# fish11.jpg   fish249.jpg  fish378.jpg  fish506.jpg  fish635.jpg  fish764.jpg
# fish120.jpg  fish24.jpg   fish379.jpg  fish507.jpg  fish636.jpg  fish765.jpg
# fish121.jpg  fish250.jpg  fish37.jpg   fish508.jpg  fish637.jpg  fish766.jpg
# fish122.jpg  fish251.jpg  fish380.jpg  fish509.jpg  fish638.jpg  fish767.jpg
# fish123.jpg  fish252.jpg  fish381.jpg  fish50.jpg   fish639.jpg  fish768.jpg
# fish124.jpg  fish253.jpg  fish382.jpg  fish510.jpg  fish63.jpg	 fish769.jpg
# fish125.jpg  fish254.jpg  fish383.jpg  fish511.jpg  fish640.jpg  fish76.jpg
# fish126.jpg  fish255.jpg  fish384.jpg  fish512.jpg  fish641.jpg  fish770.jpg
# fish127.jpg  fish256.jpg  fish385.jpg  fish513.jpg  fish642.jpg  fish771.jpg
# fish128.jpg  fish257.jpg  fish386.jpg  fish514.jpg  fish643.jpg  fish772.jpg
# fish129.jpg  fish258.jpg  fish387.jpg  fish515.jpg  fish644.jpg  fish773.jpg
# fish12.jpg   fish259.jpg  fish388.jpg  fish516.jpg  fish645.jpg  fish774.jpg
# fish130.jpg  fish25.jpg   fish389.jpg  fish517.jpg  fish646.jpg  fish775.jpg
# fish131.jpg  fish260.jpg  fish38.jpg   fish518.jpg  fish647.jpg  fish776.jpg
# fish132.jpg  fish261.jpg  fish390.jpg  fish519.jpg  fish648.jpg  fish777.jpg
# fish133.jpg  fish262.jpg  fish391.jpg  fish51.jpg   fish649.jpg  fish778.jpg
# fish134.jpg  fish263.jpg  fish392.jpg  fish520.jpg  fish64.jpg	 fish779.jpg
# fish135.jpg  fish264.png  fish393.jpg  fish521.jpg  fish650.jpg  fish77.jpg
# fish136.jpg  fish265.jpg  fish394.jpg  fish522.jpg  fish651.jpg  fish780.jpg
# fish137.jpg  fish266.jpg  fish395.jpg  fish523.jpg  fish652.jpg  fish781.jpg
# fish138.jpg  fish267.jpg  fish396.jpg  fish524.jpg  fish653.jpg  fish782.jpg
# fish139.jpg  fish268.jpg  fish397.jpg  fish525.jpg  fish654.jpg  fish783.jpg
# fish13.jpg   fish269.jpg  fish398.jpg  fish526.jpg  fish655.jpg  fish784.jpg
# fish140.jpg  fish26.jpg   fish399.jpg  fish527.jpg  fish656.jpg  fish785.jpg
# fish141.jpg  fish270.jpg  fish39.jpg   fish528.jpg  fish657.jpg  fish786.jpg
# fish142.jpg  fish271.jpg  fish3.jpg    fish529.jpg  fish658.jpg  fish787.jpg
# fish143.jpg  fish272.jpg  fish400.jpg  fish52.jpg   fish659.jpg  fish788.jpg
# fish144.jpg  fish273.jpg  fish401.jpg  fish530.jpg  fish65.jpg	 fish789.jpg
# fish145.jpg  fish274.jpg  fish402.jpg  fish531.jpg  fish660.jpg  fish78.jpg
# fish146.jpg  fish275.jpg  fish403.jpg  fish532.jpg  fish661.jpg  fish790.jpg
# fish147.jpg  fish276.jpg  fish404.jpg  fish533.jpg  fish662.jpg  fish791.jpg
# fish148.jpg  fish277.jpg  fish405.jpg  fish534.jpg  fish663.jpg  fish792.jpg
# fish149.jpg  fish278.jpg  fish406.jpg  fish535.jpg  fish664.jpg  fish793.jpg
# fish14.jpg   fish279.jpg  fish407.jpg  fish536.jpg  fish665.jpg  fish794.jpg
# fish150.jpg  fish27.jpg   fish408.jpg  fish537.jpg  fish666.jpg  fish795.jpg
# fish151.jpg  fish280.jpg  fish409.jpg  fish538.jpg  fish667.jpg  fish796.jpg
# fish152.jpg  fish281.jpg  fish40.jpg   fish539.jpg  fish668.jpg  fish797.jpg
# fish153.jpg  fish282.jpg  fish410.jpg  fish53.jpg   fish669.jpg  fish798.jpg
# fish154.jpg  fish283.jpg  fish411.jpg  fish540.jpg  fish66.jpg	 fish799.jpg
# fish155.jpg  fish284.jpg  fish412.jpg  fish541.jpg  fish670.jpg  fish79.jpg
# fish156.jpg  fish285.jpg  fish413.jpg  fish542.jpg  fish671.jpg  fish7.jpg
# fish157.jpg  fish286.jpg  fish414.jpg  fish543.jpg  fish672.jpg  fish800.jpg
# fish158.jpg  fish287.jpg  fish415.jpg  fish544.jpg  fish673.jpg  fish801.jpg
# fish159.jpg  fish288.jpg  fish416.jpg  fish545.jpg  fish674.jpg  fish802.jpg
# fish15.jpg   fish289.jpg  fish417.jpg  fish546.jpg  fish675.jpg  fish803.jpg
# fish160.jpg  fish28.jpg   fish418.jpg  fish547.jpg  fish676.jpg  fish804.jpg
# fish161.jpg  fish290.jpg  fish419.jpg  fish548.jpg  fish677.jpg  fish805.jpg
# fish162.jpg  fish291.jpg  fish41.jpg   fish549.jpg  fish678.jpg  fish806.jpg
# fish163.jpg  fish292.jpg  fish420.jpg  fish54.jpg   fish679.jpg  fish807.jpg
# fish164.jpg  fish293.jpg  fish421.jpg  fish550.jpg  fish67.jpg	 fish808.jpg
# fish165.jpg  fish294.jpg  fish422.jpg  fish551.jpg  fish680.jpg  fish809.jpg
# fish166.jpg  fish295.jpg  fish423.jpg  fish552.jpg  fish681.jpg  fish80.jpg
# fish167.jpg  fish296.jpg  fish424.jpg  fish553.jpg  fish682.jpg  fish810.jpg
# fish168.jpg  fish297.jpg  fish425.jpg  fish554.jpg  fish683.jpg  fish811.jpg
# fish169.jpg  fish298.jpg  fish426.jpg  fish555.jpg  fish684.jpg  fish812.jpg
# fish16.jpg   fish299.jpg  fish427.jpg  fish556.jpg  fish685.jpg  fish813.jpg
# fish170.jpg  fish29.jpg   fish428.jpg  fish557.jpg  fish686.jpg  fish814.jpg
# fish171.jpg  fish2.jpg	  fish429.jpg  fish558.jpg  fish687.jpg  fish815.jpg
# fish172.jpg  fish300.jpg  fish42.jpg   fish559.jpg  fish688.jpg  fish816.jpg
# fish173.jpg  fish301.jpg  fish430.png  fish55.jpg   fish689.jpg  fish817.jpg
# fish174.jpg  fish302.jpg  fish431.jpg  fish560.jpg  fish68.jpg	 fish818.jpg
# fish175.jpg  fish303.jpg  fish432.jpg  fish561.jpg  fish690.jpg  fish819.jpg
# fish176.jpg  fish304.jpg  fish433.jpg  fish562.jpg  fish691.jpg  fish81.jpg
# fish177.jpg  fish305.jpg  fish434.jpg  fish563.jpg  fish692.jpg  fish820.jpg
# fish178.jpg  fish306.jpg  fish435.jpg  fish564.jpg  fish693.jpg  fish821.jpg
# fish179.jpg  fish307.jpg  fish436.jpg  fish565.jpg  fish694.jpg  fish822.jpg
# fish17.jpg   fish308.jpg  fish437.jpg  fish566.jpg  fish695.jpg  fish823.jpg
# fish180.jpg  fish309.jpg  fish438.jpg  fish567.jpg  fish696.jpg  fish824.jpg
# fish181.jpg  fish30.jpg   fish439.jpg  fish568.jpg  fish697.jpg  fish825.jpg
# fish182.jpg  fish310.jpg  fish43.jpg   fish569.jpg  fish698.jpg  fish826.jpg
# fish183.jpg  fish311.jpg  fish440.jpg  fish56.jpg   fish699.jpg  fish827.jpg
# fish184.jpg  fish312.jpg  fish441.jpg  fish570.jpg  fish69.jpg	 fish828.jpg
# fish185.jpg  fish313.jpg  fish442.jpg  fish571.jpg  fish6.jpg	 fish829.jpg
# fish186.jpg  fish314.jpg  fish443.jpg  fish572.jpg  fish700.jpg  fish82.jpg
# fish187.jpg  fish315.jpg  fish444.jpg  fish573.jpg  fish701.jpg  fish830.jpg
# fish188.jpg  fish316.jpg  fish445.jpg  fish574.jpg  fish702.jpg  fish831.jpg
# fish189.jpg  fish317.jpg  fish446.jpg  fish575.jpg  fish703.jpg  fish832.jpg
# fish18.jpg   fish318.jpg  fish447.jpg  fish576.jpg  fish704.jpg  fish833.jpg
# fish190.jpg  fish319.jpg  fish448.jpg  fish577.jpg  fish705.jpg  fish834.jpg
# fish191.jpg  fish31.jpg   fish449.jpg  fish578.jpg  fish706.jpg  fish835.jpg
# fish192.jpg  fish320.jpg  fish44.jpg   fish579.jpg  fish707.jpg  fish836.jpg
# fish193.jpg  fish321.jpg  fish450.jpg  fish57.jpg   fish708.jpg  fish837.jpg
# fish194.jpg  fish322.jpg  fish451.jpg  fish580.jpg  fish709.jpg  fish838.jpg
# fish195.jpg  fish323.jpg  fish452.jpg  fish581.jpg  fish70.jpg	 fish839.jpg
# fish196.jpg  fish324.jpg  fish453.jpg  fish582.jpg  fish710.jpg  fish83.jpg
# fish197.jpg  fish325.jpg  fish454.jpg  fish583.jpg  fish711.jpg  fish840.jpg
# fish198.jpg  fish326.jpg  fish455.jpg  fish584.jpg  fish712.jpg  fish841.jpg
# fish199.jpg  fish327.jpg  fish456.jpg  fish585.jpg  fish713.jpg  fish842.jpg
# fish19.jpg   fish328.jpg  fish457.jpg  fish586.jpg  fish714.jpg  fish843.jpg
# fish1.jpg    fish329.jpg  fish458.jpg  fish587.jpg  fish715.jpg  fish844.jpg
# fish200.jpg  fish32.jpg   fish459.jpg  fish588.jpg  fish716.jpg  fish845.jpg
# fish201.jpg  fish330.jpg  fish45.jpg   fish589.jpg  fish717.jpg  fish846.jpg
# fish202.jpg  fish331.jpg  fish460.jpg  fish58.jpg   fish718.jpg  fish847.jpg
# fish203.jpg  fish332.jpg  fish461.jpg  fish590.jpg  fish719.jpg  fish848.jpg
# fish204.jpg  fish333.jpg  fish462.jpg  fish591.jpg  fish71.jpg	 fish849.jpg
# fish205.jpg  fish334.jpg  fish463.jpg  fish592.jpg  fish720.jpg  fish84.jpg
# fish206.jpg  fish335.jpg  fish464.jpg  fish593.jpg  fish721.jpg  fish850.jpg
# fish207.png  fish336.jpg  fish465.jpg  fish594.jpg  fish722.jpg  fish851.jpg
# fish208.jpg  fish337.jpg  fish466.jpg  fish595.jpg  fish723.jpg  fish852.jpg
# fish209.jpg  fish338.jpg  fish467.jpg  fish596.jpg  fish724.jpg  fish853.jpg
# fish20.jpg   fish339.jpg  fish468.jpg  fish597.jpg  fish725.jpg  fish854.jpg
# fish210.jpg  fish33.jpg   fish469.jpg  fish598.jpg  fish726.jpg  fish855.jpg
# fish211.jpg  fish340.jpg  fish46.jpg   fish599.jpg  fish727.jpg  fish85.jpg
# fish212.jpg  fish341.jpg  fish470.jpg  fish59.jpg   fish728.jpg  fish86.jpg
# fish213.jpg  fish342.jpg  fish471.jpg  fish5.jpg    fish729.jpg  fish87.jpg
# fish214.jpg  fish343.jpg  fish472.jpg  fish600.jpg  fish72.jpg	 fish88.jpg
# fish215.jpg  fish344.jpg  fish473.jpg  fish601.jpg  fish730.jpg  fish89.jpg
# fish216.jpg  fish345.jpg  fish474.jpg  fish602.jpg  fish731.jpg  fish8.jpg
# fish217.jpg  fish346.jpg  fish475.jpg  fish603.jpg  fish732.jpg  fish90.jpg
# fish218.jpg  fish347.jpg  fish476.jpg  fish604.jpg  fish733.jpg  fish91.jpg
# fish219.jpg  fish348.jpg  fish477.jpg  fish605.jpg  fish734.jpg  fish92.jpg
# fish21.jpg   fish349.jpg  fish478.jpg  fish606.jpg  fish735.jpg  fish93.jpg
# fish220.jpg  fish34.jpg   fish479.jpg  fish607.jpg  fish736.jpg  fish94.jpg
# fish221.jpg  fish350.jpg  fish47.jpg   fish608.jpg  fish737.jpg  fish95.jpg
# fish222.jpg  fish351.jpg  fish480.jpg  fish609.jpg  fish738.jpg  fish96.jpg
# fish223.jpg  fish352.jpg  fish481.jpg  fish60.jpg   fish739.jpg  fish97.jpg
# fish224.jpg  fish353.jpg  fish482.jpg  fish610.jpg  fish73.jpg	 fish98.jpg
# fish225.jpg  fish354.jpg  fish483.jpg  fish611.jpg  fish740.jpg  fish99.jpg
# fish226.jpg  fish355.jpg  fish484.jpg  fish612.jpg  fish741.jpg  fish9.jpg
# fish227.jpg  fish356.jpg  fish485.jpg  fish613.jpg  fish742.jpg
# fish228.jpg  fish357.jpg  fish486.jpg  fish614.jpg  fish743.jpg
# fish229.jpg  fish358.jpg  fish487.jpg  fish615.jpg  fish744.jpg

# %% [markdown]
# ## Convert Your Images
#
# You must convert your images into a data set form that PyTorch can directly utilize. The following command converts your images and writes the resulting data set to another directory.

# %%
CMD = "python /content/stylegan2-ada-pytorch/dataset_tool.py "\
  "--source /content/drive/MyDrive/JellyFish "\
  "--dest /content/drive/MyDrive/data/gan/dataset/circuit"

# !{CMD}
# Out:
# Error: --dest folder must be empty

# %% [markdown]
# You can use the following command to clear out the newly created dataset.  If something goes wrong and you need to clean up your images and rerun the above command, you should delete your partially completed dataset directory.

# %%
#!rm -R /content/drive/MyDrive/data/gan/dataset/circuit/*

# %% [markdown]
# ## Clean Up your Images
#
# All images must have the same dimensions and color depth.  This code can identify images that have issues.

# %%
from os import listdir
from os.path import isfile, join
import os
from PIL import Image
from tqdm.notebook import tqdm

IMAGE_PATH = '/content/drive/MyDrive/data/gan/dataset/circuit/00000'
files = [f for f in listdir(IMAGE_PATH) if isfile(join(IMAGE_PATH, f))]

base_size = None
for file in tqdm(files):
  file2 = os.path.join(IMAGE_PATH,file)
  img = Image.open(file2)
  sz = img.size
  if base_size and sz!=base_size:
    print(f"Inconsistant size: {file2}")
  elif img.mode!='RGB':
    print(f"Inconsistant color format: {file2}")
  else:
    base_size = sz
# Out:
#   0%|          | 0/120 [00:00<?, ?it/s]

# %% [markdown]
# ## Perform Initial Training
#
# This code performs the initial training.  Set SNAP low enough to get a snapshot before Colab forces you to quit.

# %%
import os

# Modify these to suit your needs
EXPERIMENTS = "/content/drive/MyDrive/data/gan/experiments"
DATA = "/content/drive/MyDrive/data/gan/dataset/circuit/00000"
SNAP = 10

# Build the command and run it
cmd = f"/usr/bin/python3 /content/stylegan2-ada-pytorch/train.py "\
  f"--snap {SNAP} --outdir {EXPERIMENTS} --data {DATA}"
# !{cmd}
# Out:
# Training options:
# {
#   "num_gpus": 1,
#   "image_snapshot_ticks": 10,
#   "network_snapshot_ticks": 10,
#   "metrics": [
#     "fid50k_full"
#   ],
#   "random_seed": 0,
#   "training_set_kwargs": {
#     "class_name": "training.dataset.ImageFolderDataset",
#     "path": "/content/drive/MyDrive/data/gan/dataset/circuit/00000",
#     "use_labels": false,
#     "max_size": 120,
#     "xflip": false,
#     "resolution": 512
#   },
#   "data_loader_kwargs": {
#     "pin_memory": true,
#     "num_workers": 3,
#     "prefetch_factor": 2
#   },
#   "G_kwargs": {
#     "class_name": "training.networks.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 2
#     },
#     "synthesis_kwargs": {
#       "channel_base": 32768,
#       "channel_max": 512,
#       "num_fp16_res": 4,
#       "conv_clamp": 256
#     }
#   },
#   "D_kwargs": {
#     "class_name": "training.networks.Discriminator",
#     "block_kwargs": {},
#     "mapping_kwargs": {},
#     "epilogue_kwargs": {
#       "mbstd_group_size": 4
#     },
#     "channel_base": 32768,
#     "channel_max": 512,
#     "num_fp16_res": 4,
#     "conv_clamp": 256
#   },
#   "G_opt_kwargs": {
#     "class_name": "torch.optim.Adam",
#     "lr": 0.0025,
#     "betas": [
#       0,
#       0.99
#     ],
#     "eps": 1e-08
#   },
#   "D_opt_kwargs": {
#     "class_name": "torch.optim.Adam",
#     "lr": 0.0025,
#     "betas": [
#       0,
#       0.99
#     ],
#     "eps": 1e-08
#   },
#   "loss_kwargs": {
#     "class_name": "training.loss.StyleGAN2Loss",
#     "r1_gamma": 6.5536
#   },
#   "total_kimg": 25000,
#   "batch_size": 8,
#   "batch_gpu": 8,
#   "ema_kimg": 2.5,
#   "ema_rampup": 0.05,
#   "ada_target": 0.6,
#   "augment_kwargs": {
#     "class_name": "training.augment.AugmentPipe",
#     "xflip": 1,
#     "rotate90": 1,
#     "xint": 1,
#     "scale": 1,
#     "rotate": 1,
#     "aniso": 1,
#     "xfrac": 1,
#     "brightness": 1,
#     "contrast": 1,
#     "lumaflip": 1,
#     "hue": 1,
#     "saturation": 1
#   },
#   "run_dir": "/content/drive/MyDrive/data/gan/experiments/00003-00000-auto1"
# }
#
# Output directory:   /content/drive/MyDrive/data/gan/experiments/00003-00000-auto1
# Training data:      /content/drive/MyDrive/data/gan/dataset/circuit/00000
# Training duration:  25000 kimg
# Number of GPUs:     1
# Number of images:   120
# Image resolution:   512
# Conditional model:  False
# Dataset x-flips:    False
#
# Creating output directory...
# Launching processes...
# Loading training set...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 3 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
#
# Num images:  120
# Image shape: [3, 512, 512]
# Label shape: [0]
#
# Constructing networks...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
#
# Generator             Parameters  Buffers  Output shape        Datatype
# ---                   ---         ---      ---                 ---
# mapping.fc0           262656      -        [8, 512]            float32
# mapping.fc1           262656      -        [8, 512]            float32
# mapping               -           512      [8, 16, 512]        float32
# synthesis.b4.conv1    2622465     32       [8, 512, 4, 4]      float32
# synthesis.b4.torgb    264195      -        [8, 3, 4, 4]        float32
# synthesis.b4:0        8192        16       [8, 512, 4, 4]      float32
# synthesis.b4:1        -           -        [8, 512, 4, 4]      float32
# synthesis.b8.conv0    2622465     80       [8, 512, 8, 8]      float32
# synthesis.b8.conv1    2622465     80       [8, 512, 8, 8]      float32
# synthesis.b8.torgb    264195      -        [8, 3, 8, 8]        float32
# synthesis.b8:0        -           16       [8, 512, 8, 8]      float32
# synthesis.b8:1        -           -        [8, 512, 8, 8]      float32
# synthesis.b16.conv0   2622465     272      [8, 512, 16, 16]    float32
# synthesis.b16.conv1   2622465     272      [8, 512, 16, 16]    float32
# synthesis.b16.torgb   264195      -        [8, 3, 16, 16]      float32
# synthesis.b16:0       -           16       [8, 512, 16, 16]    float32
# synthesis.b16:1       -           -        [8, 512, 16, 16]    float32
# synthesis.b32.conv0   2622465     1040     [8, 512, 32, 32]    float32
# synthesis.b32.conv1   2622465     1040     [8, 512, 32, 32]    float32
# synthesis.b32.torgb   264195      -        [8, 3, 32, 32]      float32
# synthesis.b32:0       -           16       [8, 512, 32, 32]    float32
# synthesis.b32:1       -           -        [8, 512, 32, 32]    float32
# synthesis.b64.conv0   2622465     4112     [8, 512, 64, 64]    float16
# synthesis.b64.conv1   2622465     4112     [8, 512, 64, 64]    float16
# synthesis.b64.torgb   264195      -        [8, 3, 64, 64]      float16
# synthesis.b64:0       -           16       [8, 512, 64, 64]    float16
# synthesis.b64:1       -           -        [8, 512, 64, 64]    float32
# synthesis.b128.conv0  1442561     16400    [8, 256, 128, 128]  float16
# synthesis.b128.conv1  721409      16400    [8, 256, 128, 128]  float16
# synthesis.b128.torgb  132099      -        [8, 3, 128, 128]    float16
# synthesis.b128:0      -           16       [8, 256, 128, 128]  float16
# synthesis.b128:1      -           -        [8, 256, 128, 128]  float32
# synthesis.b256.conv0  426369      65552    [8, 128, 256, 256]  float16
# synthesis.b256.conv1  213249      65552    [8, 128, 256, 256]  float16
# synthesis.b256.torgb  66051       -        [8, 3, 256, 256]    float16
# synthesis.b256:0      -           16       [8, 128, 256, 256]  float16
# synthesis.b256:1      -           -        [8, 128, 256, 256]  float32
# synthesis.b512.conv0  139457      262160   [8, 64, 512, 512]   float16
# synthesis.b512.conv1  69761       262160   [8, 64, 512, 512]   float16
# synthesis.b512.torgb  33027       -        [8, 3, 512, 512]    float16
# synthesis.b512:0      -           16       [8, 64, 512, 512]   float16
# synthesis.b512:1      -           -        [8, 64, 512, 512]   float32
# ---                   ---         ---      ---                 ---
# Total                 28700647    699904   -                   -
#
#
# Discriminator  Parameters  Buffers  Output shape        Datatype
# ---            ---         ---      ---                 ---
# b512.fromrgb   256         16       [8, 64, 512, 512]   float16
# b512.skip      8192        16       [8, 128, 256, 256]  float16
# b512.conv0     36928       16       [8, 64, 512, 512]   float16
# b512.conv1     73856       16       [8, 128, 256, 256]  float16
# b512           -           16       [8, 128, 256, 256]  float16
# b256.skip      32768       16       [8, 256, 128, 128]  float16
# b256.conv0     147584      16       [8, 128, 256, 256]  float16
# b256.conv1     295168      16       [8, 256, 128, 128]  float16
# b256           -           16       [8, 256, 128, 128]  float16
# b128.skip      131072      16       [8, 512, 64, 64]    float16
# b128.conv0     590080      16       [8, 256, 128, 128]  float16
# b128.conv1     1180160     16       [8, 512, 64, 64]    float16
# b128           -           16       [8, 512, 64, 64]    float16
# b64.skip       262144      16       [8, 512, 32, 32]    float16
# b64.conv0      2359808     16       [8, 512, 64, 64]    float16
# b64.conv1      2359808     16       [8, 512, 32, 32]    float16
# b64            -           16       [8, 512, 32, 32]    float16
# b32.skip       262144      16       [8, 512, 16, 16]    float32
# b32.conv0      2359808     16       [8, 512, 32, 32]    float32
# b32.conv1      2359808     16       [8, 512, 16, 16]    float32
# b32            -           16       [8, 512, 16, 16]    float32
# b16.skip       262144      16       [8, 512, 8, 8]      float32
# b16.conv0      2359808     16       [8, 512, 16, 16]    float32
# b16.conv1      2359808     16       [8, 512, 8, 8]      float32
# b16            -           16       [8, 512, 8, 8]      float32
# b8.skip        262144      16       [8, 512, 4, 4]      float32
# b8.conv0       2359808     16       [8, 512, 8, 8]      float32
# b8.conv1       2359808     16       [8, 512, 4, 4]      float32
# b8             -           16       [8, 512, 4, 4]      float32
# b4.mbstd       -           -        [8, 513, 4, 4]      float32
# b4.conv        2364416     16       [8, 512, 4, 4]      float32
# b4.fc          4194816     -        [8, 512]            float32
# b4.out         513         -        [8, 1]              float32
# ---            ---         ---      ---                 ---
# Total          28982849    480      -                   -
#
# Setting up augmentation...
# Distributing across 1 GPUs...
# Setting up training phases...
# Exporting sample images...
# Initializing logs...
# 2022-10-05 23:53:13.422065: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-05 23:53:14.678206: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-10-05 23:53:16.561583: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2022-10-05 23:53:16.561831: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2022-10-05 23:53:16.561856: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Training for 25000 kimg...
#
# tick 0     kimg 0.0      time 1m 32s       sec/tick 14.4    sec/kimg 1805.04 maintenance 77.4   cpumem 4.88   gpumem 9.97   augment 0.000
# Evaluating metrics...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 3 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# {"results": {"fid50k_full": 303.64990639419693}, "metric": "fid50k_full", "total_time": 1405.978971004486, "total_time_str": "23m 26s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000000.pkl", "timestamp": 1665015435.1363838}
# tick 1     kimg 4.0      time 41m 26s      sec/tick 972.0   sec/kimg 242.99  maintenance 1421.7 cpumem 5.47   gpumem 7.46   augment 0.005
# tick 2     kimg 8.0      time 57m 40s      sec/tick 973.9   sec/kimg 243.46  maintenance 0.3    cpumem 5.47   gpumem 7.48   augment 0.011
# tick 3     kimg 12.0     time 1h 13m 56s   sec/tick 976.5   sec/kimg 244.12  maintenance 0.2    cpumem 5.47   gpumem 7.49   augment 0.017
# tick 4     kimg 16.0     time 1h 30m 14s   sec/tick 977.7   sec/kimg 244.42  maintenance 0.2    cpumem 5.47   gpumem 7.48   augment 0.024
# tick 5     kimg 20.0     time 1h 46m 32s   sec/tick 977.0   sec/kimg 244.25  maintenance 0.3    cpumem 5.47   gpumem 7.47   augment 0.031
# tick 6     kimg 24.0     time 2h 02m 49s   sec/tick 977.1   sec/kimg 244.28  maintenance 0.2    cpumem 5.47   gpumem 7.53   augment 0.038
# tick 7     kimg 28.0     time 2h 19m 08s   sec/tick 979.1   sec/kimg 244.79  maintenance 0.2    cpumem 5.47   gpumem 7.59   augment 0.045
# tick 8     kimg 32.0     time 2h 35m 29s   sec/tick 980.3   sec/kimg 245.06  maintenance 0.3    cpumem 5.47   gpumem 7.51   augment 0.051
# tick 9     kimg 36.0     time 2h 51m 49s   sec/tick 979.9   sec/kimg 244.98  maintenance 0.3    cpumem 5.47   gpumem 7.50   augment 0.057
# tick 10    kimg 40.0     time 3h 08m 10s   sec/tick 980.4   sec/kimg 245.09  maintenance 0.3    cpumem 5.47   gpumem 7.56   augment 0.063
# Evaluating metrics...
# {"results": {"fid50k_full": 280.2419461058309}, "metric": "fid50k_full", "total_time": 1389.6155178546906, "total_time_str": "23m 10s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000040.pkl", "timestamp": 1665026620.557593}
# tick 11    kimg 44.0     time 3h 48m 00s   sec/tick 980.9   sec/kimg 245.23  maintenance 1409.4 cpumem 6.05   gpumem 7.65   augment 0.069
# tick 12    kimg 48.0     time 4h 04m 22s   sec/tick 982.2   sec/kimg 245.55  maintenance 0.3    cpumem 6.04   gpumem 7.52   augment 0.075
# tick 13    kimg 52.0     time 4h 20m 45s   sec/tick 982.7   sec/kimg 245.66  maintenance 0.3    cpumem 6.03   gpumem 7.55   augment 0.080
# tick 14    kimg 56.0     time 4h 37m 07s   sec/tick 981.8   sec/kimg 245.46  maintenance 0.3    cpumem 6.02   gpumem 7.52   augment 0.085
# tick 15    kimg 60.0     time 4h 53m 30s   sec/tick 982.0   sec/kimg 245.51  maintenance 0.2    cpumem 6.00   gpumem 7.61   augment 0.091
# tick 16    kimg 64.0     time 5h 09m 54s   sec/tick 984.3   sec/kimg 246.07  maintenance 0.3    cpumem 5.98   gpumem 7.58   augment 0.096
# tick 17    kimg 68.0     time 5h 26m 17s   sec/tick 983.0   sec/kimg 245.75  maintenance 0.3    cpumem 5.97   gpumem 7.65   augment 0.099
# tick 18    kimg 72.0     time 5h 42m 40s   sec/tick 981.9   sec/kimg 245.48  maintenance 0.3    cpumem 5.95   gpumem 7.55   augment 0.105
# tick 19    kimg 76.0     time 5h 59m 03s   sec/tick 983.0   sec/kimg 245.76  maintenance 0.2    cpumem 5.94   gpumem 7.56   augment 0.110
# tick 20    kimg 80.0     time 6h 15m 28s   sec/tick 984.3   sec/kimg 246.08  maintenance 0.3    cpumem 5.93   gpumem 7.61   augment 0.115
# Evaluating metrics...
# {"results": {"fid50k_full": 205.6270660531976}, "metric": "fid50k_full", "total_time": 1394.053287267685, "total_time_str": "23m 14s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000080.pkl", "timestamp": 1665037859.9731426}
# tick 21    kimg 84.0     time 6h 55m 21s   sec/tick 982.5   sec/kimg 245.62  maintenance 1410.9 cpumem 5.65   gpumem 7.58   augment 0.120
# tick 22    kimg 88.0     time 7h 11m 44s   sec/tick 982.6   sec/kimg 245.66  maintenance 0.2    cpumem 5.63   gpumem 7.58   augment 0.126
# tick 23    kimg 92.0     time 7h 28m 08s   sec/tick 984.0   sec/kimg 246.01  maintenance 0.2    cpumem 5.62   gpumem 7.56   augment 0.131
# tick 24    kimg 96.0     time 7h 44m 33s   sec/tick 984.7   sec/kimg 246.18  maintenance 0.3    cpumem 5.59   gpumem 7.59   augment 0.135
# tick 25    kimg 100.0    time 8h 00m 57s   sec/tick 984.1   sec/kimg 246.03  maintenance 0.3    cpumem 5.57   gpumem 7.67   augment 0.140
# tick 26    kimg 104.0    time 8h 17m 23s   sec/tick 984.9   sec/kimg 246.22  maintenance 0.3    cpumem 5.57   gpumem 7.63   augment 0.144
# tick 27    kimg 108.0    time 8h 33m 48s   sec/tick 985.0   sec/kimg 246.24  maintenance 0.3    cpumem 5.57   gpumem 7.65   augment 0.149
# tick 28    kimg 112.0    time 8h 50m 14s   sec/tick 986.2   sec/kimg 246.54  maintenance 0.3    cpumem 5.57   gpumem 7.67   augment 0.153
# tick 29    kimg 116.0    time 9h 06m 40s   sec/tick 985.9   sec/kimg 246.48  maintenance 0.3    cpumem 5.56   gpumem 7.64   augment 0.156
# tick 30    kimg 120.0    time 9h 23m 06s   sec/tick 985.4   sec/kimg 246.34  maintenance 0.3    cpumem 5.55   gpumem 7.65   augment 0.161
# Evaluating metrics...
# {"results": {"fid50k_full": 320.9486073017962}, "metric": "fid50k_full", "total_time": 1391.9128563404083, "total_time_str": "23m 12s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000120.pkl", "timestamp": 1665049119.3463922}
# tick 31    kimg 124.0    time 10h 03m 04s  sec/tick 986.3   sec/kimg 246.59  maintenance 1411.8 cpumem 5.84   gpumem 7.69   augment 0.166
# tick 32    kimg 128.0    time 10h 19m 30s  sec/tick 985.2   sec/kimg 246.29  maintenance 0.3    cpumem 5.82   gpumem 7.64   augment 0.173
# tick 33    kimg 132.0    time 10h 35m 55s  sec/tick 985.6   sec/kimg 246.39  maintenance 0.3    cpumem 5.81   gpumem 7.77   augment 0.177
# tick 34    kimg 136.0    time 10h 52m 22s  sec/tick 986.5   sec/kimg 246.62  maintenance 0.2    cpumem 5.80   gpumem 7.59   augment 0.181
# tick 35    kimg 140.0    time 11h 08m 49s  sec/tick 986.7   sec/kimg 246.68  maintenance 0.3    cpumem 5.80   gpumem 7.67   augment 0.183
# tick 36    kimg 144.0    time 11h 25m 17s  sec/tick 987.4   sec/kimg 246.84  maintenance 0.3    cpumem 5.80   gpumem 7.66   augment 0.186
# tick 37    kimg 148.0    time 11h 41m 43s  sec/tick 986.3   sec/kimg 246.58  maintenance 0.3    cpumem 5.80   gpumem 7.62   augment 0.190
# tick 38    kimg 152.0    time 11h 58m 11s  sec/tick 987.4   sec/kimg 246.85  maintenance 0.3    cpumem 5.80   gpumem 7.65   augment 0.193
# tick 39    kimg 156.0    time 12h 14m 39s  sec/tick 987.7   sec/kimg 246.92  maintenance 0.3    cpumem 5.80   gpumem 7.62   augment 0.196
# tick 40    kimg 160.0    time 12h 31m 07s  sec/tick 988.2   sec/kimg 247.05  maintenance 0.3    cpumem 5.80   gpumem 7.71   augment 0.199
# Evaluating metrics...
# {"results": {"fid50k_full": 217.4268465238831}, "metric": "fid50k_full", "total_time": 1389.0186920166016, "total_time_str": "23m 09s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000160.pkl", "timestamp": 1665060395.7297053}
# tick 41    kimg 164.0    time 13h 11m 03s  sec/tick 988.6   sec/kimg 247.16  maintenance 1406.8 cpumem 5.81   gpumem 7.63   augment 0.201
# tick 42    kimg 168.0    time 13h 27m 31s  sec/tick 988.2   sec/kimg 247.05  maintenance 0.3    cpumem 5.79   gpumem 7.65   augment 0.203
# tick 43    kimg 172.0    time 13h 43m 59s  sec/tick 987.1   sec/kimg 246.78  maintenance 0.3    cpumem 5.79   gpumem 7.64   augment 0.207
# tick 44    kimg 176.0    time 14h 00m 28s  sec/tick 988.9   sec/kimg 247.23  maintenance 0.3    cpumem 5.76   gpumem 7.63   augment 0.212
# tick 45    kimg 180.0    time 14h 16m 57s  sec/tick 988.8   sec/kimg 247.21  maintenance 0.3    cpumem 5.76   gpumem 7.67   augment 0.215
# tick 46    kimg 184.0    time 14h 33m 26s  sec/tick 988.5   sec/kimg 247.14  maintenance 0.3    cpumem 5.76   gpumem 7.66   augment 0.218
# tick 47    kimg 188.0    time 14h 49m 55s  sec/tick 988.7   sec/kimg 247.17  maintenance 0.3    cpumem 5.76   gpumem 7.87   augment 0.220
# tick 48    kimg 192.0    time 15h 06m 25s  sec/tick 989.8   sec/kimg 247.45  maintenance 0.3    cpumem 5.76   gpumem 7.68   augment 0.220
# tick 49    kimg 196.0    time 15h 22m 54s  sec/tick 988.8   sec/kimg 247.20  maintenance 0.3    cpumem 5.76   gpumem 7.67   augment 0.222
# tick 50    kimg 200.0    time 15h 39m 22s  sec/tick 988.2   sec/kimg 247.05  maintenance 0.3    cpumem 5.77   gpumem 7.62   augment 0.223
# Evaluating metrics...
# {"results": {"fid50k_full": 180.15177197652918}, "metric": "fid50k_full", "total_time": 1388.749410867691, "total_time_str": "23m 09s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000200.pkl", "timestamp": 1665071689.9413002}
# tick 51    kimg 204.0    time 16h 19m 17s  sec/tick 989.0   sec/kimg 247.26  maintenance 1406.1 cpumem 5.65   gpumem 7.68   augment 0.225
# tick 52    kimg 208.0    time 16h 35m 48s  sec/tick 990.2   sec/kimg 247.55  maintenance 0.3    cpumem 5.65   gpumem 7.65   augment 0.227
# tick 53    kimg 212.0    time 16h 52m 17s  sec/tick 989.3   sec/kimg 247.31  maintenance 0.3    cpumem 5.65   gpumem 7.62   augment 0.228
# tick 54    kimg 216.0    time 17h 08m 47s  sec/tick 989.1   sec/kimg 247.28  maintenance 0.3    cpumem 5.65   gpumem 7.61   augment 0.230
# tick 55    kimg 220.0    time 17h 25m 16s  sec/tick 989.1   sec/kimg 247.27  maintenance 0.3    cpumem 5.64   gpumem 7.64   augment 0.233
# tick 56    kimg 224.0    time 17h 41m 46s  sec/tick 990.0   sec/kimg 247.50  maintenance 0.3    cpumem 5.63   gpumem 7.65   augment 0.233
# tick 57    kimg 228.0    time 17h 58m 15s  sec/tick 988.5   sec/kimg 247.13  maintenance 0.3    cpumem 5.62   gpumem 7.64   augment 0.237
# tick 58    kimg 232.0    time 18h 14m 44s  sec/tick 988.8   sec/kimg 247.20  maintenance 0.3    cpumem 5.61   gpumem 7.66   augment 0.239
# tick 59    kimg 236.0    time 18h 31m 13s  sec/tick 988.9   sec/kimg 247.22  maintenance 0.3    cpumem 5.61   gpumem 7.70   augment 0.243
# tick 60    kimg 240.0    time 18h 47m 44s  sec/tick 990.7   sec/kimg 247.68  maintenance 0.3    cpumem 5.61   gpumem 7.65   augment 0.246
# Evaluating metrics...
# {"results": {"fid50k_full": 130.30879391648557}, "metric": "fid50k_full", "total_time": 1390.3223552703857, "total_time_str": "23m 10s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000240.pkl", "timestamp": 1665082991.7713547}
# tick 61    kimg 244.0    time 19h 27m 40s  sec/tick 989.4   sec/kimg 247.36  maintenance 1405.9 cpumem 5.81   gpumem 7.64   augment 0.248
# tick 62    kimg 248.0    time 19h 44m 09s  sec/tick 989.3   sec/kimg 247.34  maintenance 0.3    cpumem 5.81   gpumem 7.67   augment 0.252
# tick 63    kimg 252.0    time 20h 00m 39s  sec/tick 989.5   sec/kimg 247.37  maintenance 0.3    cpumem 5.81   gpumem 7.63   augment 0.256
# tick 64    kimg 256.0    time 20h 17m 10s  sec/tick 991.0   sec/kimg 247.75  maintenance 0.3    cpumem 5.81   gpumem 7.75   augment 0.259
# tick 65    kimg 260.0    time 20h 33m 40s  sec/tick 989.8   sec/kimg 247.45  maintenance 0.3    cpumem 5.81   gpumem 7.84   augment 0.261
# tick 66    kimg 264.0    time 20h 50m 11s  sec/tick 990.2   sec/kimg 247.54  maintenance 0.3    cpumem 5.81   gpumem 7.66   augment 0.265
# tick 67    kimg 268.0    time 21h 06m 41s  sec/tick 989.7   sec/kimg 247.42  maintenance 0.3    cpumem 5.81   gpumem 7.66   augment 0.268
# tick 68    kimg 272.0    time 21h 23m 12s  sec/tick 990.6   sec/kimg 247.65  maintenance 0.3    cpumem 5.81   gpumem 7.81   augment 0.272
# tick 69    kimg 276.0    time 21h 39m 42s  sec/tick 990.5   sec/kimg 247.61  maintenance 0.3    cpumem 5.81   gpumem 7.70   augment 0.276
# tick 70    kimg 280.0    time 21h 56m 13s  sec/tick 990.4   sec/kimg 247.60  maintenance 0.3    cpumem 5.81   gpumem 7.69   augment 0.279
# Evaluating metrics...
# {"results": {"fid50k_full": 96.90752523159557}, "metric": "fid50k_full", "total_time": 1391.4883441925049, "total_time_str": "23m 11s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000280.pkl", "timestamp": 1665094303.0130363}
# tick 71    kimg 284.0    time 22h 36m 12s  sec/tick 990.7   sec/kimg 247.68  maintenance 1408.5 cpumem 5.81   gpumem 7.68   augment 0.283
# tick 72    kimg 288.0    time 22h 52m 43s  sec/tick 991.0   sec/kimg 247.76  maintenance 0.3    cpumem 5.81   gpumem 7.65   augment 0.287
# tick 73    kimg 292.0    time 23h 09m 14s  sec/tick 989.8   sec/kimg 247.45  maintenance 0.3    cpumem 5.81   gpumem 7.64   augment 0.292
# tick 74    kimg 296.0    time 23h 25m 44s  sec/tick 990.5   sec/kimg 247.62  maintenance 0.3    cpumem 5.81   gpumem 7.71   augment 0.297

# %% [markdown]
# ## Resume Training
#
# You can now resume training after you are interrupted by something in the pervious step.

# %%
import os

# Modify these to suit your needs
EXPERIMENTS = "/content/drive/MyDrive/data/gan/experiments"
NETWORK = "network-snapshot-000280.pkl"
RESUME = os.path.join(EXPERIMENTS, \
                "00003-00000-auto1", NETWORK)
DATA = "/content/drive/MyDrive/data/gan/dataset/circuit"
SNAP = 10

# Build the command and run it
cmd = f"/usr/bin/python3 /content/stylegan2-ada-pytorch/train.py "\
  f"--snap {SNAP} --resume {RESUME} --outdir {EXPERIMENTS} --data {DATA}"
# !{cmd}
# Out:
# Training options:
# {
#   "num_gpus": 1,
#   "image_snapshot_ticks": 10,
#   "network_snapshot_ticks": 10,
#   "metrics": [
#     "fid50k_full"
#   ],
#   "random_seed": 0,
#   "training_set_kwargs": {
#     "class_name": "training.dataset.ImageFolderDataset",
#     "path": "/content/drive/MyDrive/data/gan/dataset/circuit",
#     "use_labels": false,
#     "max_size": 120,
#     "xflip": false,
#     "resolution": 512
#   },
#   "data_loader_kwargs": {
#     "pin_memory": true,
#     "num_workers": 3,
#     "prefetch_factor": 2
#   },
#   "G_kwargs": {
#     "class_name": "training.networks.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 2
#     },
#     "synthesis_kwargs": {
#       "channel_base": 32768,
#       "channel_max": 512,
#       "num_fp16_res": 4,
#       "conv_clamp": 256
#     }
#   },
#   "D_kwargs": {
#     "class_name": "training.networks.Discriminator",
#     "block_kwargs": {},
#     "mapping_kwargs": {},
#     "epilogue_kwargs": {
#       "mbstd_group_size": 4
#     },
#     "channel_base": 32768,
#     "channel_max": 512,
#     "num_fp16_res": 4,
#     "conv_clamp": 256
#   },
#   "G_opt_kwargs": {
#     "class_name": "torch.optim.Adam",
#     "lr": 0.0025,
#     "betas": [
#       0,
#       0.99
#     ],
#     "eps": 1e-08
#   },
#   "D_opt_kwargs": {
#     "class_name": "torch.optim.Adam",
#     "lr": 0.0025,
#     "betas": [
#       0,
#       0.99
#     ],
#     "eps": 1e-08
#   },
#   "loss_kwargs": {
#     "class_name": "training.loss.StyleGAN2Loss",
#     "r1_gamma": 6.5536
#   },
#   "total_kimg": 25000,
#   "batch_size": 8,
#   "batch_gpu": 8,
#   "ema_kimg": 2.5,
#   "ema_rampup": null,
#   "ada_target": 0.6,
#   "augment_kwargs": {
#     "class_name": "training.augment.AugmentPipe",
#     "xflip": 1,
#     "rotate90": 1,
#     "xint": 1,
#     "scale": 1,
#     "rotate": 1,
#     "aniso": 1,
#     "xfrac": 1,
#     "brightness": 1,
#     "contrast": 1,
#     "lumaflip": 1,
#     "hue": 1,
#     "saturation": 1
#   },
#   "resume_pkl": "/content/drive/MyDrive/data/gan/experiments/00003-00000-auto1/network-snapshot-000280.pkl",
#   "ada_kimg": 100,
#   "run_dir": "/content/drive/MyDrive/data/gan/experiments/00005-circuit-auto1-resumecustom"
# }
#
# Output directory:   /content/drive/MyDrive/data/gan/experiments/00005-circuit-auto1-resumecustom
# Training data:      /content/drive/MyDrive/data/gan/dataset/circuit
# Training duration:  25000 kimg
# Number of GPUs:     1
# Number of images:   120
# Image resolution:   512
# Conditional model:  False
# Dataset x-flips:    False
#
# Creating output directory...
# Launching processes...
# Loading training set...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 3 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
#
# Num images:  120
# Image shape: [3, 512, 512]
# Label shape: [0]
#
# Constructing networks...
# Resuming from "/content/drive/MyDrive/data/gan/experiments/00003-00000-auto1/network-snapshot-000280.pkl"
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
#
# Generator             Parameters  Buffers  Output shape        Datatype
# ---                   ---         ---      ---                 ---
# mapping.fc0           262656      -        [8, 512]            float32
# mapping.fc1           262656      -        [8, 512]            float32
# mapping               -           512      [8, 16, 512]        float32
# synthesis.b4.conv1    2622465     32       [8, 512, 4, 4]      float32
# synthesis.b4.torgb    264195      -        [8, 3, 4, 4]        float32
# synthesis.b4:0        8192        16       [8, 512, 4, 4]      float32
# synthesis.b4:1        -           -        [8, 512, 4, 4]      float32
# synthesis.b8.conv0    2622465     80       [8, 512, 8, 8]      float32
# synthesis.b8.conv1    2622465     80       [8, 512, 8, 8]      float32
# synthesis.b8.torgb    264195      -        [8, 3, 8, 8]        float32
# synthesis.b8:0        -           16       [8, 512, 8, 8]      float32
# synthesis.b8:1        -           -        [8, 512, 8, 8]      float32
# synthesis.b16.conv0   2622465     272      [8, 512, 16, 16]    float32
# synthesis.b16.conv1   2622465     272      [8, 512, 16, 16]    float32
# synthesis.b16.torgb   264195      -        [8, 3, 16, 16]      float32
# synthesis.b16:0       -           16       [8, 512, 16, 16]    float32
# synthesis.b16:1       -           -        [8, 512, 16, 16]    float32
# synthesis.b32.conv0   2622465     1040     [8, 512, 32, 32]    float32
# synthesis.b32.conv1   2622465     1040     [8, 512, 32, 32]    float32
# synthesis.b32.torgb   264195      -        [8, 3, 32, 32]      float32
# synthesis.b32:0       -           16       [8, 512, 32, 32]    float32
# synthesis.b32:1       -           -        [8, 512, 32, 32]    float32
# synthesis.b64.conv0   2622465     4112     [8, 512, 64, 64]    float16
# synthesis.b64.conv1   2622465     4112     [8, 512, 64, 64]    float16
# synthesis.b64.torgb   264195      -        [8, 3, 64, 64]      float16
# synthesis.b64:0       -           16       [8, 512, 64, 64]    float16
# synthesis.b64:1       -           -        [8, 512, 64, 64]    float32
# synthesis.b128.conv0  1442561     16400    [8, 256, 128, 128]  float16
# synthesis.b128.conv1  721409      16400    [8, 256, 128, 128]  float16
# synthesis.b128.torgb  132099      -        [8, 3, 128, 128]    float16
# synthesis.b128:0      -           16       [8, 256, 128, 128]  float16
# synthesis.b128:1      -           -        [8, 256, 128, 128]  float32
# synthesis.b256.conv0  426369      65552    [8, 128, 256, 256]  float16
# synthesis.b256.conv1  213249      65552    [8, 128, 256, 256]  float16
# synthesis.b256.torgb  66051       -        [8, 3, 256, 256]    float16
# synthesis.b256:0      -           16       [8, 128, 256, 256]  float16
# synthesis.b256:1      -           -        [8, 128, 256, 256]  float32
# synthesis.b512.conv0  139457      262160   [8, 64, 512, 512]   float16
# synthesis.b512.conv1  69761       262160   [8, 64, 512, 512]   float16
# synthesis.b512.torgb  33027       -        [8, 3, 512, 512]    float16
# synthesis.b512:0      -           16       [8, 64, 512, 512]   float16
# synthesis.b512:1      -           -        [8, 64, 512, 512]   float32
# ---                   ---         ---      ---                 ---
# Total                 28700647    699904   -                   -
#
#
# Discriminator  Parameters  Buffers  Output shape        Datatype
# ---            ---         ---      ---                 ---
# b512.fromrgb   256         16       [8, 64, 512, 512]   float16
# b512.skip      8192        16       [8, 128, 256, 256]  float16
# b512.conv0     36928       16       [8, 64, 512, 512]   float16
# b512.conv1     73856       16       [8, 128, 256, 256]  float16
# b512           -           16       [8, 128, 256, 256]  float16
# b256.skip      32768       16       [8, 256, 128, 128]  float16
# b256.conv0     147584      16       [8, 128, 256, 256]  float16
# b256.conv1     295168      16       [8, 256, 128, 128]  float16
# b256           -           16       [8, 256, 128, 128]  float16
# b128.skip      131072      16       [8, 512, 64, 64]    float16
# b128.conv0     590080      16       [8, 256, 128, 128]  float16
# b128.conv1     1180160     16       [8, 512, 64, 64]    float16
# b128           -           16       [8, 512, 64, 64]    float16
# b64.skip       262144      16       [8, 512, 32, 32]    float16
# b64.conv0      2359808     16       [8, 512, 64, 64]    float16
# b64.conv1      2359808     16       [8, 512, 32, 32]    float16
# b64            -           16       [8, 512, 32, 32]    float16
# b32.skip       262144      16       [8, 512, 16, 16]    float32
# b32.conv0      2359808     16       [8, 512, 32, 32]    float32
# b32.conv1      2359808     16       [8, 512, 16, 16]    float32
# b32            -           16       [8, 512, 16, 16]    float32
# b16.skip       262144      16       [8, 512, 8, 8]      float32
# b16.conv0      2359808     16       [8, 512, 16, 16]    float32
# b16.conv1      2359808     16       [8, 512, 8, 8]      float32
# b16            -           16       [8, 512, 8, 8]      float32
# b8.skip        262144      16       [8, 512, 4, 4]      float32
# b8.conv0       2359808     16       [8, 512, 8, 8]      float32
# b8.conv1       2359808     16       [8, 512, 4, 4]      float32
# b8             -           16       [8, 512, 4, 4]      float32
# b4.mbstd       -           -        [8, 513, 4, 4]      float32
# b4.conv        2364416     16       [8, 512, 4, 4]      float32
# b4.fc          4194816     -        [8, 512]            float32
# b4.out         513         -        [8, 1]              float32
# ---            ---         ---      ---                 ---
# Total          28982849    480      -                   -
#
# Setting up augmentation...
# Distributing across 1 GPUs...
# Setting up training phases...
# Exporting sample images...
# Initializing logs...
# Training for 25000 kimg...
#
# tick 0     kimg 0.0      time 1m 44s       sec/tick 14.2    sec/kimg 1778.75 maintenance 89.7   cpumem 5.47   gpumem 10.33  augment 0.000
# Evaluating metrics...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 3 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# {"results": {"fid50k_full": 96.72538498042448}, "metric": "fid50k_full", "total_time": 1411.4000825881958, "total_time_str": "23m 31s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000000.pkl", "timestamp": 1665101323.5164464}
# tick 1     kimg 4.0      time 42m 05s      sec/tick 994.2   sec/kimg 248.55  maintenance 1426.5 cpumem 5.94   gpumem 7.49   augment 0.040
# tick 2     kimg 8.0      time 58m 40s      sec/tick 995.3   sec/kimg 248.82  maintenance 0.3    cpumem 5.94   gpumem 7.54   augment 0.079
# tick 3     kimg 12.0     time 1h 15m 18s   sec/tick 997.6   sec/kimg 249.40  maintenance 0.3    cpumem 5.94   gpumem 7.69   augment 0.119
# tick 4     kimg 16.0     time 1h 31m 58s   sec/tick 1000.1  sec/kimg 250.02  maintenance 0.3    cpumem 5.94   gpumem 7.60   augment 0.158
# tick 5     kimg 20.0     time 1h 48m 40s   sec/tick 1001.0  sec/kimg 250.26  maintenance 0.3    cpumem 5.94   gpumem 7.60   augment 0.195
# tick 6     kimg 24.0     time 2h 05m 23s   sec/tick 1002.7  sec/kimg 250.67  maintenance 0.3    cpumem 5.94   gpumem 7.63   augment 0.227
# tick 7     kimg 28.0     time 2h 22m 07s   sec/tick 1003.8  sec/kimg 250.94  maintenance 0.3    cpumem 5.94   gpumem 7.70   augment 0.259
# tick 8     kimg 32.0     time 2h 38m 52s   sec/tick 1005.2  sec/kimg 251.30  maintenance 0.3    cpumem 5.94   gpumem 7.66   augment 0.287
# tick 9     kimg 36.0     time 2h 55m 38s   sec/tick 1005.7  sec/kimg 251.42  maintenance 0.3    cpumem 5.94   gpumem 7.71   augment 0.312
# tick 10    kimg 40.0     time 3h 12m 25s   sec/tick 1006.2  sec/kimg 251.54  maintenance 0.3    cpumem 5.94   gpumem 7.76   augment 0.333
# Evaluating metrics...
# {"results": {"fid50k_full": 93.97288466665947}, "metric": "fid50k_full", "total_time": 1403.6448769569397, "total_time_str": "23m 24s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000040.pkl", "timestamp": 1665112756.2700255}
# tick 11    kimg 44.0     time 3h 52m 50s   sec/tick 1007.1  sec/kimg 251.78  maintenance 1418.6 cpumem 5.80   gpumem 7.69   augment 0.354
# tick 12    kimg 48.0     time 4h 09m 39s   sec/tick 1008.8  sec/kimg 252.20  maintenance 0.3    cpumem 5.80   gpumem 7.66   augment 0.377
# tick 13    kimg 52.0     time 4h 26m 28s   sec/tick 1008.1  sec/kimg 252.03  maintenance 0.3    cpumem 5.80   gpumem 7.69   augment 0.391
# tick 14    kimg 56.0     time 4h 43m 16s   sec/tick 1008.1  sec/kimg 252.02  maintenance 0.3    cpumem 5.80   gpumem 7.71   augment 0.404
# tick 15    kimg 60.0     time 5h 00m 04s   sec/tick 1008.0  sec/kimg 252.00  maintenance 0.3    cpumem 5.80   gpumem 7.71   augment 0.418
# tick 16    kimg 64.0     time 5h 16m 53s   sec/tick 1008.8  sec/kimg 252.20  maintenance 0.3    cpumem 5.80   gpumem 7.80   augment 0.425
# tick 17    kimg 68.0     time 5h 33m 42s   sec/tick 1008.3  sec/kimg 252.06  maintenance 0.3    cpumem 5.80   gpumem 7.73   augment 0.437
# tick 18    kimg 72.0     time 5h 50m 31s   sec/tick 1008.5  sec/kimg 252.12  maintenance 0.3    cpumem 5.80   gpumem 7.75   augment 0.452
# tick 19    kimg 76.0     time 6h 07m 19s   sec/tick 1008.2  sec/kimg 252.06  maintenance 0.3    cpumem 5.81   gpumem 7.75   augment 0.459
# tick 20    kimg 80.0     time 6h 24m 08s   sec/tick 1009.0  sec/kimg 252.26  maintenance 0.3    cpumem 5.81   gpumem 7.76   augment 0.470
# Evaluating metrics...
# {"results": {"fid50k_full": 93.57288256193628}, "metric": "fid50k_full", "total_time": 1398.4182677268982, "total_time_str": "23m 18s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000080.pkl", "timestamp": 1665124254.9490566}
# tick 21    kimg 84.0     time 7h 04m 31s   sec/tick 1008.6  sec/kimg 252.16  maintenance 1413.4 cpumem 6.35   gpumem 7.69   augment 0.470
# tick 22    kimg 88.0     time 7h 21m 19s   sec/tick 1008.7  sec/kimg 252.17  maintenance 0.3    cpumem 6.35   gpumem 7.75   augment 0.482
# tick 23    kimg 92.0     time 7h 38m 08s   sec/tick 1008.0  sec/kimg 252.00  maintenance 0.3    cpumem 6.36   gpumem 7.82   augment 0.486
# tick 24    kimg 96.0     time 7h 54m 57s   sec/tick 1008.8  sec/kimg 252.19  maintenance 0.3    cpumem 6.36   gpumem 7.72   augment 0.495
# tick 25    kimg 100.0    time 8h 11m 45s   sec/tick 1008.2  sec/kimg 252.05  maintenance 0.3    cpumem 6.36   gpumem 7.74   augment 0.504
# tick 26    kimg 104.0    time 8h 28m 35s   sec/tick 1009.4  sec/kimg 252.35  maintenance 0.3    cpumem 6.36   gpumem 7.75   augment 0.510
# tick 27    kimg 108.0    time 8h 45m 24s   sec/tick 1009.3  sec/kimg 252.33  maintenance 0.3    cpumem 6.36   gpumem 7.78   augment 0.518
# tick 28    kimg 112.0    time 9h 02m 15s   sec/tick 1010.5  sec/kimg 252.63  maintenance 0.3    cpumem 6.36   gpumem 7.75   augment 0.527
# tick 29    kimg 116.0    time 9h 19m 05s   sec/tick 1009.8  sec/kimg 252.44  maintenance 0.3    cpumem 6.36   gpumem 7.78   augment 0.537
# tick 30    kimg 120.0    time 9h 35m 56s   sec/tick 1010.0  sec/kimg 252.49  maintenance 0.3    cpumem 6.36   gpumem 7.72   augment 0.540
# Evaluating metrics...
# {"results": {"fid50k_full": 77.33837041353868}, "metric": "fid50k_full", "total_time": 1399.6618373394012, "total_time_str": "23m 20s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000120.pkl", "timestamp": 1665135763.767274}
# tick 31    kimg 124.0    time 10h 16m 22s  sec/tick 1010.8  sec/kimg 252.70  maintenance 1415.2 cpumem 6.59   gpumem 7.77   augment 0.543
# tick 32    kimg 128.0    time 10h 33m 12s  sec/tick 1010.4  sec/kimg 252.60  maintenance 0.3    cpumem 6.59   gpumem 7.75   augment 0.550
# tick 33    kimg 132.0    time 10h 50m 03s  sec/tick 1010.3  sec/kimg 252.58  maintenance 0.3    cpumem 6.59   gpumem 7.78   augment 0.557
# tick 34    kimg 136.0    time 11h 06m 53s  sec/tick 1010.4  sec/kimg 252.61  maintenance 0.3    cpumem 6.59   gpumem 7.85   augment 0.563
# tick 35    kimg 140.0    time 11h 23m 44s  sec/tick 1010.3  sec/kimg 252.56  maintenance 0.3    cpumem 6.59   gpumem 7.77   augment 0.572
# tick 36    kimg 144.0    time 11h 40m 36s  sec/tick 1011.3  sec/kimg 252.81  maintenance 0.3    cpumem 6.59   gpumem 7.76   augment 0.581
# tick 37    kimg 148.0    time 11h 57m 26s  sec/tick 1010.6  sec/kimg 252.64  maintenance 0.3    cpumem 6.59   gpumem 7.76   augment 0.588
# tick 38    kimg 152.0    time 12h 14m 17s  sec/tick 1010.9  sec/kimg 252.72  maintenance 0.3    cpumem 6.59   gpumem 7.75   augment 0.599
# tick 39    kimg 156.0    time 12h 31m 08s  sec/tick 1010.5  sec/kimg 252.62  maintenance 0.3    cpumem 6.59   gpumem 7.82   augment 0.610
# tick 40    kimg 160.0    time 12h 48m 00s  sec/tick 1011.8  sec/kimg 252.95  maintenance 0.3    cpumem 6.59   gpumem 7.74   augment 0.616
# Evaluating metrics...
# {"results": {"fid50k_full": 78.52909783074723}, "metric": "fid50k_full", "total_time": 1397.4187467098236, "total_time_str": "23m 17s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000160.pkl", "timestamp": 1665147285.8494177}
# tick 41    kimg 164.0    time 13h 28m 25s  sec/tick 1012.2  sec/kimg 253.04  maintenance 1412.5 cpumem 6.65   gpumem 7.84   augment 0.621
# tick 42    kimg 168.0    time 13h 45m 18s  sec/tick 1012.4  sec/kimg 253.09  maintenance 0.3    cpumem 6.65   gpumem 7.81   augment 0.625
# tick 43    kimg 172.0    time 14h 02m 10s  sec/tick 1011.8  sec/kimg 252.95  maintenance 0.3    cpumem 6.65   gpumem 7.77   augment 0.632
# tick 44    kimg 176.0    time 14h 19m 03s  sec/tick 1013.5  sec/kimg 253.37  maintenance 0.3    cpumem 6.65   gpumem 7.74   augment 0.636
# tick 45    kimg 180.0    time 14h 35m 56s  sec/tick 1012.2  sec/kimg 253.05  maintenance 0.3    cpumem 6.65   gpumem 7.82   augment 0.645
# tick 46    kimg 184.0    time 14h 52m 48s  sec/tick 1012.3  sec/kimg 253.06  maintenance 0.3    cpumem 6.65   gpumem 7.80   augment 0.654
# tick 47    kimg 188.0    time 15h 09m 41s  sec/tick 1012.8  sec/kimg 253.19  maintenance 0.3    cpumem 6.65   gpumem 7.80   augment 0.665
# tick 48    kimg 192.0    time 15h 26m 34s  sec/tick 1012.4  sec/kimg 253.11  maintenance 0.3    cpumem 6.64   gpumem 7.78   augment 0.674
# tick 49    kimg 196.0    time 15h 43m 26s  sec/tick 1011.3  sec/kimg 252.83  maintenance 0.3    cpumem 6.64   gpumem 7.82   augment 0.684
# tick 50    kimg 200.0    time 16h 00m 17s  sec/tick 1011.5  sec/kimg 252.87  maintenance 0.3    cpumem 6.64   gpumem 7.88   augment 0.692
# Evaluating metrics...
# {"results": {"fid50k_full": 71.08381648393654}, "metric": "fid50k_full", "total_time": 1400.5161714553833, "total_time_str": "23m 21s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000200.pkl", "timestamp": 1665158827.6652958}
# tick 51    kimg 204.0    time 16h 40m 47s  sec/tick 1012.4  sec/kimg 253.10  maintenance 1417.2 cpumem 6.55   gpumem 7.84   augment 0.704
# tick 52    kimg 208.0    time 16h 57m 40s  sec/tick 1012.6  sec/kimg 253.14  maintenance 0.3    cpumem 6.53   gpumem 7.74   augment 0.711
# tick 53    kimg 212.0    time 17h 14m 32s  sec/tick 1012.2  sec/kimg 253.05  maintenance 0.3    cpumem 6.52   gpumem 7.82   augment 0.724
# tick 54    kimg 216.0    time 17h 31m 25s  sec/tick 1012.8  sec/kimg 253.21  maintenance 0.3    cpumem 6.52   gpumem 7.81   augment 0.734
# tick 55    kimg 220.0    time 17h 48m 19s  sec/tick 1013.4  sec/kimg 253.35  maintenance 0.3    cpumem 6.52   gpumem 7.84   augment 0.741
# tick 56    kimg 224.0    time 18h 05m 12s  sec/tick 1013.1  sec/kimg 253.27  maintenance 0.3    cpumem 6.52   gpumem 7.81   augment 0.747
# tick 57    kimg 228.0    time 18h 22m 05s  sec/tick 1012.7  sec/kimg 253.16  maintenance 0.3    cpumem 6.52   gpumem 7.86   augment 0.752
# tick 58    kimg 232.0    time 18h 38m 58s  sec/tick 1012.6  sec/kimg 253.16  maintenance 0.3    cpumem 6.52   gpumem 7.86   augment 0.763
# tick 59    kimg 236.0    time 18h 55m 51s  sec/tick 1012.7  sec/kimg 253.17  maintenance 0.3    cpumem 6.52   gpumem 7.85   augment 0.772
# tick 60    kimg 240.0    time 19h 12m 45s  sec/tick 1014.0  sec/kimg 253.49  maintenance 0.3    cpumem 6.52   gpumem 7.85   augment 0.784
# Evaluating metrics...
# {"results": {"fid50k_full": 78.40089526330816}, "metric": "fid50k_full", "total_time": 1401.768121957779, "total_time_str": "23m 22s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000240.pkl", "timestamp": 1665170375.236967}
# tick 61    kimg 244.0    time 19h 53m 16s  sec/tick 1013.6  sec/kimg 253.40  maintenance 1416.8 cpumem 6.44   gpumem 7.84   augment 0.792
# tick 62    kimg 248.0    time 20h 10m 10s  sec/tick 1014.1  sec/kimg 253.53  maintenance 0.3    cpumem 6.43   gpumem 7.80   augment 0.798
# tick 63    kimg 252.0    time 20h 27m 03s  sec/tick 1013.1  sec/kimg 253.27  maintenance 0.3    cpumem 6.42   gpumem 7.86   augment 0.808
# tick 64    kimg 256.0    time 20h 43m 58s  sec/tick 1014.7  sec/kimg 253.68  maintenance 0.3    cpumem 6.41   gpumem 7.83   augment 0.817
# tick 65    kimg 260.0    time 21h 00m 53s  sec/tick 1014.0  sec/kimg 253.51  maintenance 0.3    cpumem 6.36   gpumem 7.87   augment 0.825
# tick 66    kimg 264.0    time 21h 17m 47s  sec/tick 1014.2  sec/kimg 253.56  maintenance 0.3    cpumem 6.35   gpumem 7.91   augment 0.834
# tick 67    kimg 268.0    time 21h 34m 42s  sec/tick 1014.6  sec/kimg 253.65  maintenance 0.3    cpumem 6.35   gpumem 7.88   augment 0.844
# tick 68    kimg 272.0    time 21h 51m 38s  sec/tick 1016.0  sec/kimg 254.01  maintenance 0.3    cpumem 6.35   gpumem 7.86   augment 0.855
# tick 69    kimg 276.0    time 22h 08m 34s  sec/tick 1015.4  sec/kimg 253.85  maintenance 0.3    cpumem 6.35   gpumem 7.89   augment 0.863
# tick 70    kimg 280.0    time 22h 25m 30s  sec/tick 1015.3  sec/kimg 253.83  maintenance 0.3    cpumem 6.35   gpumem 7.85   augment 0.868
# Evaluating metrics...
# {"results": {"fid50k_full": 82.62493848153916}, "metric": "fid50k_full", "total_time": 1399.499749660492, "total_time_str": "23m 19s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000280.pkl", "timestamp": 1665181937.3346877}
# tick 71    kimg 284.0    time 23h 06m 00s  sec/tick 1015.5  sec/kimg 253.87  maintenance 1414.6 cpumem 6.11   gpumem 7.85   augment 0.880
# tick 72    kimg 288.0    time 23h 22m 56s  sec/tick 1016.1  sec/kimg 254.03  maintenance 0.3    cpumem 6.11   gpumem 7.84   augment 0.890
# tick 73    kimg 292.0    time 23h 39m 52s  sec/tick 1015.6  sec/kimg 253.90  maintenance 0.3    cpumem 6.12   gpumem 8.01   augment 0.897

# %%
# !git clone https://github.com/NVlabs/stylegan3.git
# !pip install ninja
# Out:
# Cloning into 'stylegan3'...
# remote: Enumerating objects: 207, done.
# remote: Total 207 (delta 0), reused 0 (delta 0), pack-reused 207
# Receiving objects: 100% (207/207), 4.16 MiB | 15.72 MiB/s, done.
# Resolving deltas: 100% (101/101), done.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: ninja in /usr/local/lib/python3.7/dist-packages (1.10.2.4)

# %%
# !ls /content/stylegan3
# Out:
# avg_spectra.py	 Dockerfile	  gen_video.py	metrics      train.py
# calc_metrics.py  docs		  gui_utils	README.md    visualizer.py
# dataset_tool.py  environment.yml  legacy.py	torch_utils  viz
# dnnlib		 gen_images.py	  LICENSE.txt	training

# %%
# HIDE OUTPUT
URL = "/content/drive/MyDrive/data/gan/experiments/00005-circuit-auto1-resumecustom/network-snapshot-000280.pkl"

# !python /content/stylegan3/gen_images.py \
    --network={URL} \
  --outdir=/content/results --seeds=6600-6625
# Out:
# Loading networks from "/content/drive/MyDrive/data/gan/experiments/00005-circuit-auto1-resumecustom/network-snapshot-000280.pkl"...
# Generating image for seed 6600 (0/26) ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Generating image for seed 6601 (1/26) ...
# Generating image for seed 6602 (2/26) ...
# Generating image for seed 6603 (3/26) ...
# Generating image for seed 6604 (4/26) ...
# Generating image for seed 6605 (5/26) ...
# Generating image for seed 6606 (6/26) ...
# Generating image for seed 6607 (7/26) ...
# Generating image for seed 6608 (8/26) ...
# Generating image for seed 6609 (9/26) ...
# Generating image for seed 6610 (10/26) ...
# Generating image for seed 6611 (11/26) ...
# Generating image for seed 6612 (12/26) ...
# Generating image for seed 6613 (13/26) ...
# Generating image for seed 6614 (14/26) ...
# Generating image for seed 6615 (15/26) ...
# Generating image for seed 6616 (16/26) ...
# Generating image for seed 6617 (17/26) ...
# Generating image for seed 6618 (18/26) ...
# Generating image for seed 6619 (19/26) ...
# Generating image for seed 6620 (20/26) ...
# Generating image for seed 6621 (21/26) ...
# Generating image for seed 6622 (22/26) ...
# Generating image for seed 6623 (23/26) ...
# Generating image for seed 6624 (24/26) ...
# Generating image for seed 6625 (25/26) ...

# %%
# !ls /content/results
# Out:
# seed6600.png  seed6606.png  seed6612.png  seed6618.png	seed6624.png
# seed6601.png  seed6607.png  seed6613.png  seed6619.png	seed6625.png
# seed6602.png  seed6608.png  seed6614.png  seed6620.png
# seed6603.png  seed6609.png  seed6615.png  seed6621.png
# seed6604.png  seed6610.png  seed6616.png  seed6622.png
# seed6605.png  seed6611.png  seed6617.png  seed6623.png

# %%
# !cp /content/results/* \
    /content/drive/MyDrive/jellyfish_result

# %%
import sys
sys.path.insert(0, "/content/stylegan3")
import pickle
import os
import numpy as np
import PIL.Image
from IPython.display import Image
import matplotlib.pyplot as plt
import IPython.display
import torch
import dnnlib
import legacy

def seed2vec(G, seed):
  return np.random.RandomState(seed).randn(1, G.z_dim)

def display_image(image):
  plt.axis('off')
  plt.imshow(image)
  plt.show()

def generate_image(G, z, truncation_psi):
    # Render images for dlatents initialized from random seeds.
    Gs_kwargs = {
        'output_transform': dict(func=tflib.convert_images_to_uint8, 
         nchw_to_nhwc=True),
        'randomize_noise': False
    }
    if truncation_psi is not None:
        Gs_kwargs['truncation_psi'] = truncation_psi

    label = np.zeros([1] + G.input_shapes[1][1:])
    # [minibatch, height, width, channel]
    images = G.run(z, label, **G_kwargs) 
    return images[0]

def get_label(G, device, class_idx):
  label = torch.zeros([1, G.c_dim], device=device)
  if G.c_dim != 0:
      if class_idx is None:
          ctx.fail("Must specify class label with --class when using "\
            "a conditional network")
      label[:, class_idx] = 1
  else:
      if class_idx is not None:
          print ("warn: --class=lbl ignored when running on "\
            "an unconditional network")
  return label

def generate_image(device, G, z, truncation_psi=1.0, noise_mode='const', 
                   class_idx=None):
  z = torch.from_numpy(z).to(device)
  label = get_label(G, device, class_idx)
  img = G(z, label, truncation_psi=truncation_psi, noise_mode=noise_mode)
  img = (img.permute(0, 2, 3, 1) * 127.5 + 128).clamp(0, 255).to(\
      torch.uint8)
  return PIL.Image.fromarray(img[0].cpu().numpy(), 'RGB')

# %%
#URL = "https://github.com/jeffheaton/pretrained-gan-fish/releases/"\
#  "download/1.0.0/fish-gan-2020-12-09.pkl"
#URL = "https://github.com/jeffheaton/pretrained-merry-gan-mas/releases/"\
#  "download/v1/christmas-gan-2020-12-03.pkl"
URL = "/content/drive/MyDrive/data/gan/experiments/00005-circuit-auto1-resumecustom/network-snapshot-000280.pkl"

print(f'Loading networks from "{URL}"...')
device = torch.device('cuda')
with dnnlib.util.open_url(URL) as f:
    G = legacy.load_network_pkl(f)['G_ema'].to(device) # type: ignore
# Out:
# Loading networks from "/content/drive/MyDrive/data/gan/experiments/00005-circuit-auto1-resumecustom/network-snapshot-000280.pkl"...

# %%
# Choose your own starting and ending seed.
SEED_FROM = 1050
SEED_TO = 1080

# Generate the images for the seeds.
for i in range(SEED_FROM, SEED_TO):
  print(f"Seed {i}")
  z = seed2vec(G, i)
  img = generate_image(device, G, z)
  display_image(img)
# Out:
# Seed 1050
# Seed 1051
# Seed 1052
# Seed 1053
# Seed 1054
# Seed 1055
# Seed 1056
# Seed 1057
# Seed 1058
# Seed 1059
# Seed 1060
# Seed 1061
# Seed 1062
# Seed 1063
# Seed 1064
# Seed 1065
# Seed 1066
# Seed 1067
# Seed 1068
# Seed 1069
# Seed 1070
# Seed 1071
# Seed 1072
# Seed 1073
# Seed 1074
# Seed 1075
# Seed 1076
# Seed 1077
# Seed 1078
# Seed 1079

# %%
def expand_seed(seeds, vector_size):
  result = []

  for seed in seeds:
    rnd = np.random.RandomState(seed)
    result.append( rnd.randn(1, vector_size) ) 
  return result

#URL = "https://github.com/jeffheaton/pretrained-gan-fish/releases/"\
#  "download/1.0.0/fish-gan-2020-12-09.pkl"
#URL = "https://github.com/jeffheaton/pretrained-merry-gan-mas/releases/"\
#  "download/v1/christmas-gan-2020-12-03.pkl"
#URL = "https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada/pretrained/ffhq.pkl"
URL = "/content/drive/MyDrive/data/gan/experiments/00005-circuit-auto1-resumecustom/network-snapshot-000280.pkl"

print(f'Loading networks from "{URL}"...')
device = torch.device('cuda')
with dnnlib.util.open_url(URL) as f:
    G = legacy.load_network_pkl(f)['G_ema'].to(device) # type: ignore

vector_size = G.z_dim
# range(8192,8300)
seeds = expand_seed( [8192+1,8192+9], vector_size)
#generate_images(Gs, seeds,truncation_psi=0.5)
print(seeds[0].shape)
# Out:
# Loading networks from "/content/drive/MyDrive/data/gan/experiments/00005-circuit-auto1-resumecustom/network-snapshot-000280.pkl"...
# (1, 512)

# %%
# HIDE OUTPUT
# Choose your seeds to morph through and the number of steps to 
# take to get to each.

#SEEDS = [6624,6618,6616] # Better for faces
SEEDS = [1014,1017,1019,1022,1027,1029,1034,1037,1041,1049,1060,1071,1078] # Better for fish
STEPS = 100

# Remove any prior results
# !rm /content/results/* 

from tqdm.notebook import tqdm

os.makedirs("./results/", exist_ok=True)

# Generate the images for the video.
idx = 0
for i in range(len(SEEDS)-1):
  v1 = seed2vec(G, SEEDS[i])
  v2 = seed2vec(G, SEEDS[i+1])

  diff = v2 - v1
  step = diff / STEPS
  current = v1.copy()

  for j in tqdm(range(STEPS), desc=f"Seed {SEEDS[i]}"):
    current = current + step
    img = generate_image(device, G, current)
    img.save(f'./results/frame-{idx}.png')
    idx+=1
 
# Link the images into a video.
# !ffmpeg -r 30 -i /content/results/frame-%d.png -vcodec mpeg4 -y movie.mp4
# Out:
# Seed 1014:   0%|          | 0/100 [00:00<?, ?it/s]
# Seed 1017:   0%|          | 0/100 [00:00<?, ?it/s]
# Seed 1019:   0%|          | 0/100 [00:00<?, ?it/s]
# Seed 1022:   0%|          | 0/100 [00:00<?, ?it/s]
# Seed 1027:   0%|          | 0/100 [00:00<?, ?it/s]
# Seed 1029:   0%|          | 0/100 [00:00<?, ?it/s]
# Seed 1034:   0%|          | 0/100 [00:00<?, ?it/s]
# Seed 1037:   0%|          | 0/100 [00:00<?, ?it/s]
# Seed 1041:   0%|          | 0/100 [00:00<?, ?it/s]
# Seed 1049:   0%|          | 0/100 [00:00<?, ?it/s]
# Seed 1060:   0%|          | 0/100 [00:00<?, ?it/s]
# Seed 1071:   0%|          | 0/100 [00:00<?, ?it/s]
# ffmpeg version 3.4.11-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from '/content/results/frame-%d.png':
#   Duration: 00:00:48.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgb24(pc), 512x512, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> mpeg4 (native))
# Press [q] to stop, [?] for help
# Output #0, mp4, to 'movie.mp4':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: mpeg4 (mp4v / 0x7634706D), yuv420p, 512x512, q=2-31, 200 kb/s, 30 fps, 15360 tbn, 30 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 mpeg4
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame= 1200 fps=196 q=31.0 Lsize=    1242kB time=00:00:39.96 bitrate= 254.6kbits/s speed=6.54x
# video:1236kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.479902%

# %%
from google.colab import files
files.download('movie.mp4')
